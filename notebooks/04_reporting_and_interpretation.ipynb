# %%
# !pip install pandas matplotlib seaborn -q

# %%
import pandas as pd

# %%
dataset_summary = pd.DataFrame({
    "Item": [
        "Dataset",
        "Modality",
        "Analysis Type",
        "Subject Used",
        "Primary Contrast",
        "Additional Contrasts"
    ],
    "Value": [
        "Haxby",
        "Task fMRI",
        "First-Level GLM",
        "Subject 1",
        "Face > House",
        "Face > Scrambled, House > Scrambled, Cat > Bottle"
    ]
})

dataset_summary
# Out:
#                    Item                                              Value
# 0               Dataset                                              Haxby
# 1              Modality                                          Task fMRI
# 2         Analysis Type                                    First-Level GLM
# 3          Subject Used                                          Subject 1
# 4      Primary Contrast                                       Face > House
# 5  Additional Contrasts  Face > Scrambled, House > Scrambled, Cat > Bottle

# %%
methods = pd.DataFrame({
    "Step": [
        "Data Fetching",
        "Label Processing",
        "Event Construction",
        "HRF Modelling",
        "Voxelwise GLM",
        "Contrast Testing",
        "Visualization"
    ],
    "Implementation": [
        "nilearn.datasets.fetch_haxby()",
        "Session target labels loaded",
        "Onset/duration/trial_type table built",
        "SPM HRF",
        "FirstLevelModel",
        "Linear contrasts",
        "plot_stat_map"
    ]
})

methods
# Out:
#                  Step                         Implementation
# 0       Data Fetching         nilearn.datasets.fetch_haxby()
# 1    Label Processing           Session target labels loaded
# 2  Event Construction  Onset/duration/trial_type table built
# 3       HRF Modelling                                SPM HRF
# 4       Voxelwise GLM                        FirstLevelModel
# 5    Contrast Testing                       Linear contrasts
# 6       Visualization                          plot_stat_map

# %%
results = pd.DataFrame({
    "Output": [
        "Design Matrix",
        "Face vs House Map",
        "Face vs Scrambled Map",
        "House vs Scrambled Map",
        "Cat vs Bottle Map"
    ],
    "Status": [
        "Generated",
        "Generated",
        "Generated",
        "Generated",
        "Generated"
    ]
})

results
# Out:
#                    Output     Status
# 0           Design Matrix  Generated
# 1       Face vs House Map  Generated
# 2   Face vs Scrambled Map  Generated
# 3  House vs Scrambled Map  Generated
# 4       Cat vs Bottle Map  Generated

# %%
interpretation = [
    "The design matrix confirmed successful encoding of multiple stimulus categories.",
    "Face vs House contrast demonstrated category-selective neural responses.",
    "Additional contrasts expanded the analysis beyond a single hypothesis.",
    "The project demonstrates end-to-end task-fMRI statistical inference.",
    "This repository complements prior resting-state and ML-based repositories."
]

for i, note in enumerate(interpretation, 1):
    print(f"{i}. {note}")
# Out:
# 1. The design matrix confirmed successful encoding of multiple stimulus categories.
# 2. Face vs House contrast demonstrated category-selective neural responses.
# 3. Additional contrasts expanded the analysis beyond a single hypothesis.
# 4. The project demonstrates end-to-end task-fMRI statistical inference.
# 5. This repository complements prior resting-state and ML-based repositories.

# %%
print("Repo 5 Complete")
print("Task-fMRI GLM workflow successfully implemented and documented.")
# Out:
# Repo 5 Complete
# Task-fMRI GLM workflow successfully implemented and documented.
